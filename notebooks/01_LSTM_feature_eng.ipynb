# %%
import os
os.chdir("..")

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
data_folder = "data/raw_data/Stock_OHLC_Data"

# %%
for file in os.listdir(data_folder):
    if file.endswith(".csv"):
        file_path = os.path.join(data_folder, file)
        df = pd.read_csv(file_path)
        df['Date'] = pd.to_datetime(df['Date'])
        df.set_index('Date', inplace=True)
        print(f"\nFile: {file}")
        df.info()
        print("Columns:", list(df.columns))
# Out:
# File: AAPL.csv
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 3754 entries, 2010-02-02 to 2024-12-31
# Data columns (total 11 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Adj Close  3754 non-null   float64
#  1   Close      3754 non-null   float64
#  2   High       3754 non-null   float64
#  3   Low        3754 non-null   float64
#  4   Open       3754 non-null   float64
#  5   Volume     3754 non-null   int64
#  6   DailyRet   3754 non-null   float64
#  7   20DayRet   3754 non-null   float64
#  8   20DayVol   3754 non-null   float64
#  9   Z20DayRet  3754 non-null   float64
#  10  Z20DayVol  3754 non-null   float64
# dtypes: float64(10), int64(1)
# memory usage: 351.9 KB
# Columns: ['Adj Close', 'Close', 'High', 'Low', 'Open', 'Volume', 'DailyRet', '20DayRet', '20DayVol', 'Z20DayRet', 'Z20DayVol']
#
# File: ABT.csv
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 3754 entries, 2010-02-02 to 2024-12-31
# Data columns (total 11 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Adj Close  3754 non-null   float64
#  1   Close      3754 non-null   float64
#  2   High       3754 non-null   float64
#  3   Low        3754 non-null   float64
#  4   Open       3754 non-null   float64
#  5   Volume     3754 non-null   int64
#  6   DailyRet   3754 non-null   float64
#  7   20DayRet   3754 non-null   float64
#  8   20DayVol   3754 non-null   float64
#  9   Z20DayRet  3754 non-null   float64
#  10  Z20DayVol  3754 non-null   float64
# dtypes: float64(10), int64(1)
# memory usage: 351.9 KB
# Columns: ['Adj Close', 'Close', 'High', 'Low', 'Open', 'Volume', 'DailyRet', '20DayRet', '20DayVol', 'Z20DayRet', 'Z20DayVol']
#
# File: ADBE.csv
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 3754 entries, 2010-02-02 to 2024-12-31
# Data columns (total 11 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Adj Close  3754 non-null   float64
#  1   Close      3754 non-null   float64
#  2   High       3754 non-null   float64
#  3   Low        3754 non-null   float64
#  4   Open       3754 non-null   float64
#  5   Volume     3754 non-null   int64
#  6   DailyRet   3754 non-null   float64
#  7   20DayRet   3754 non-null   float64
#  8   20DayVol   3754 non-null   float64
#  9   Z20DayRet  3754 non-null   float64
#  10  Z20DayVol  3754 non-null   float64
# dtypes: float64(10), int64(1)
# memory usage: 351.9 KB
# Columns: ['Adj Close', 'Close', 'High', 'Low', 'Open', 'Volume', 'DailyRet', '20DayRet', '20DayVol', 'Z20DayRet', 'Z20DayVol']
#
# File: AMGN.csv
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 3754 entries, 2010-02-02 to 2024-12-31
# Data columns (total 11 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Adj Close  3754 non-null   float64
#  1   Close      3754 non-null   float64
#  2   High       3754 non-null   float64
#  3   Low        3754 non-null   float64
#  4   Open       3754 non-null   float64
#  5   Volume     3754 non-null   int64
#  6   DailyRet   3754 non-null   float64
#  7   20DayRet   3754 non-null   float64
#  8   20DayVol   3754 non-null   float64
#  9   Z20DayRet  3754 non-null   float64
#  10  Z20DayVol  3754 non-null   float64
# dtypes: float64(10), int64(1)
# memory usage: 351.9 KB
# Columns: ['Adj Close', 'Close', 'High', 'Low', 'Open', 'Volume', 'DailyRet', '20DayRet', '20DayVol', 'Z20DayRet', 'Z20DayVol']
#
# File: AMZN.csv
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 3754 entries, 2010-02-02 to 2024-12-31
# Data columns (total 11 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Adj Close  3754 non-null   float64
#  1   Close      3754 non-null   float64
#  2   High       3754 non-null   float64
#  3   Low        3754 non-null   float64
#  4   Open       3754 non-null   float64
#  5   Volume     3754 non-null   int64
#  6   DailyRet   3754 non-null   float64
#  7   20DayRet   3754 non-null   float64
#  8   20DayVol   3754 non-null   float64
#  9   Z20DayRet  3754 non-null   float64
#  10  Z20DayVol  3754 non-null   float64
# dtypes: float64(10), int64(1)
# memory usage: 351.9 KB
# Columns: ['Adj Close', 'Close', 'High', 'Low', 'Open', 'Volume', 'DailyRet', '20DayRet', '20DayVol', 'Z20DayRet', 'Z20DayVol']
#
# File: BA.csv
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 3754 entries, 2010-02-02 to 2024-12-31
# Data columns (total 11 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Adj Close  3754 non-null   float64
#  1   Close      3754 non-null   float64
#  2   High       3754 non-null   float64
#  3   Low        3754 non-null   float64
#  4   Open       3754 non-null   float64
#  5   Volume     3754 non-null   int64
#  6   DailyRet   3754 non-null   float64
#  7   20DayRet   3754 non-null   float64
#  8   20DayVol   3754 non-null   float64
#  9   Z20DayRet  3754 non-null   float64
#  10  Z20DayVol  3754 non-null   float64
# dtypes: float64(10), int64(1)
# memory usage: 351.9 KB
# Columns: ['Adj Close', 'Close', 'High', 'Low', 'Open', 'Volume', 'DailyRet', '20DayRet', '20DayVol', 'Z20DayRet', 'Z20DayVol']
#
# File: BKNG.csv
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 3754 entries, 2010-02-02 to 2024-12-31
# Data columns (total 11 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Adj Close  3754 non-null   float64
#  1   Close      3754 non-null   float64
#  2   High       3754 non-null   float64
#  3   Low        3754 non-null   float64
#  4   Open       3754 non-null   float64
#  5   Volume     3754 non-null   int64
#  6   DailyRet   3754 non-null   float64
#  7   20DayRet   3754 non-null   float64
#  8   20DayVol   3754 non-null   float64
#  9   Z20DayRet  3754 non-null   float64
#  10  Z20DayVol  3754 non-null   float64
# dtypes: float64(10), int64(1)
# memory usage: 351.9 KB
# Columns: ['Adj Close', 'Close', 'High', 'Low', 'Open', 'Volume', 'DailyRet', '20DayRet', '20DayVol', 'Z20DayRet', 'Z20DayVol']
#
# File: BLK.csv
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 3754 entries, 2010-02-02 to 2024-12-31
# Data columns (total 11 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Adj Close  3754 non-null   float64
#  1   Close      3754 non-null   float64
#  2   High       3754 non-null   float64
#  3   Low        3754 non-null   float64
#  4   Open       3754 non-null   float64
#  5   Volume     3754 non-null   int64
#  6   DailyRet   3754 non-null   float64
#  7   20DayRet   3754 non-null   float64
#  8   20DayVol   3754 non-null   float64
#  9   Z20DayRet  3754 non-null   float64
#  10  Z20DayVol  3754 non-null   float64
# dtypes: float64(10), int64(1)
# memory usage: 351.9 KB
# Columns: ['Adj Close', 'Close', 'High', 'Low', 'Open', 'Volume', 'DailyRet', '20DayRet', '20DayVol', 'Z20DayRet', 'Z20DayVol']
#
# File: BMY.csv
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 3754 entries, 2010-02-02 to 2024-12-31
# Data columns (total 11 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Adj Close  3754 non-null   float64
#  1   Close      3754 non-null   float64
#  2   High       3754 non-null   float64
#  3   Low        3754 non-null   float64
#  4   Open       3754 non-null   float64
#  5   Volume     3754 non-null   int64
#  6   DailyRet   3754 non-null   float64
#  7   20DayRet   3754 non-null   float64
#  8   20DayVol   3754 non-null   float64
#  9   Z20DayRet  3754 non-null   float64
#  10  Z20DayVol  3754 non-null   float64
# dtypes: float64(10), int64(1)
# memory usage: 351.9 KB
# Columns: ['Adj Close', 'Close', 'High', 'Low', 'Open', 'Volume', 'DailyRet', '20DayRet', '20DayVol', 'Z20DayRet', 'Z20DayVol']
#
# File: CAT.csv
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 3754 entries, 2010-02-02 to 2024-12-31
# Data columns (total 11 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Adj Close  3754 non-null   float64
#  1   Close      3754 non-null   float64
#  2   High       3754 non-null   float64
#  3   Low        3754 non-null   float64
#  4   Open       3754 non-null   float64
#  5   Volume     3754 non-null   int64
#  6   DailyRet   3754 non-null   float64
#  7   20DayRet   3754 non-null   float64
#  8   20DayVol   3754 non-null   float64
#  9   Z20DayRet  3754 non-null   float64
#  10  Z20DayVol  3754 non-null   float64
# dtypes: float64(10), int64(1)
# memory usage: 351.9 KB
# Columns: ['Adj Close', 'Close', 'High', 'Low', 'Open', 'Volume', 'DailyRet', '20DayRet', '20DayVol', 'Z20DayRet', 'Z20DayVol']
#
# File: COST.csv
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 3754 entries, 2010-02-02 to 2024-12-31
# Data columns (total 11 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Adj Close  3754 non-null   float64
#  1   Close      3754 non-null   float64
#  2   High       3754 non-null   float64
#  3   Low        3754 non-null   float64
#  4   Open       3754 non-null   float64
#  5   Volume     3754 non-null   int64
#  6   DailyRet   3754 non-null   float64
#  7   20DayRet   3754 non-null   float64
#  8   20DayVol   3754 non-null   float64
#  9   Z20DayRet  3754 non-null   float64
#  10  Z20DayVol  3754 non-null   float64
# dtypes: float64(10), int64(1)
# memory usage: 351.9 KB
# Columns: ['Adj Close', 'Close', 'High', 'Low', 'Open', 'Volume', 'DailyRet', '20DayRet', '20DayVol', 'Z20DayRet', 'Z20DayVol']
#
# File: CRM.csv
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 3754 entries, 2010-02-02 to 2024-12-31
# Data columns (total 11 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Adj Close  3754 non-null   float64
#  1   Close      3754 non-null   float64
#  2   High       3754 non-null   float64
#  3   Low        3754 non-null   float64
#  4   Open       3754 non-null   float64
#  5   Volume     3754 non-null   int64
#  6   DailyRet   3754 non-null   float64
#  7   20DayRet   3754 non-null   float64
#  8   20DayVol   3754 non-null   float64
#  9   Z20DayRet  3754 non-null   float64
#  10  Z20DayVol  3754 non-null   float64
# dtypes: float64(10), int64(1)
# memory usage: 351.9 KB
# Columns: ['Adj Close', 'Close', 'High', 'Low', 'Open', 'Volume', 'DailyRet', '20DayRet', '20DayVol', 'Z20DayRet', 'Z20DayVol']
#
# File: CSCO.csv
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 3754 entries, 2010-02-02 to 2024-12-31
# Data columns (total 11 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Adj Close  3754 non-null   float64
#  1   Close      3754 non-null   float64
#  2   High       3754 non-null   float64
#  3   Low        3754 non-null   float64
#  4   Open       3754 non-null   float64
#  5   Volume     3754 non-null   int64
#  6   DailyRet   3754 non-null   float64
#  7   20DayRet   3754 non-null   float64
#  8   20DayVol   3754 non-null   float64
#  9   Z20DayRet  3754 non-null   float64
#  10  Z20DayVol  3754 non-null   float64
# dtypes: float64(10), int64(1)
# memory usage: 351.9 KB
# Columns: ['Adj Close', 'Close', 'High', 'Low', 'Open', 'Volume', 'DailyRet', '20DayRet', '20DayVol', 'Z20DayRet', 'Z20DayVol']
#
# File: CVX.csv
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 3754 entries, 2010-02-02 to 2024-12-31
# Data columns (total 11 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Adj Close  3754 non-null   float64
#  1   Close      3754 non-null   float64
#  2   High       3754 non-null   float64
#  3   Low        3754 non-null   float64
#  4   Open       3754 non-null   float64
#  5   Volume     3754 non-null   int64
#  6   DailyRet   3754 non-null   float64
#  7   20DayRet   3754 non-null   float64
#  8   20DayVol   3754 non-null   float64
#  9   Z20DayRet  3754 non-null   float64
#  10  Z20DayVol  3754 non-null   float64
# dtypes: float64(10), int64(1)
# memory usage: 351.9 KB
# Columns: ['Adj Close', 'Close', 'High', 'Low', 'Open', 'Volume', 'DailyRet', '20DayRet', '20DayVol', 'Z20DayRet', 'Z20DayVol']
#
# File: DHR.csv
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 3754 entries, 2010-02-02 to 2024-12-31
# Data columns (total 11 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Adj Close  3754 non-null   float64
#  1   Close      3754 non-null   float64
#  2   High       3754 non-null   float64
#  3   Low        3754 non-null   float64
#  4   Open       3754 non-null   float64
#  5   Volume     3754 non-null   int64
#  6   DailyRet   3754 non-null   float64
#  7   20DayRet   3754 non-null   float64
#  8   20DayVol   3754 non-null   float64
#  9   Z20DayRet  3754 non-null   float64
#  10  Z20DayVol  3754 non-null   float64
# dtypes: float64(10), int64(1)
# memory usage: 351.9 KB
# Columns: ['Adj Close', 'Close', 'High', 'Low', 'Open', 'Volume', 'DailyRet', '20DayRet', '20DayVol', 'Z20DayRet', 'Z20DayVol']
#
# File: DIS.csv
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 3754 entries, 2010-02-02 to 2024-12-31
# Data columns (total 11 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Adj Close  3754 non-null   float64
#  1   Close      3754 non-null   float64
#  2   High       3754 non-null   float64
#  3   Low        3754 non-null   float64
#  4   Open       3754 non-null   float64
#  5   Volume     3754 non-null   int64
#  6   DailyRet   3754 non-null   float64
#  7   20DayRet   3754 non-null   float64
#  8   20DayVol   3754 non-null   float64
#  9   Z20DayRet  3754 non-null   float64
#  10  Z20DayVol  3754 non-null   float64
# dtypes: float64(10), int64(1)
# memory usage: 351.9 KB
# Columns: ['Adj Close', 'Close', 'High', 'Low', 'Open', 'Volume', 'DailyRet', '20DayRet', '20DayVol', 'Z20DayRet', 'Z20DayVol']
#
# File: FIS.csv
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 3754 entries, 2010-02-02 to 2024-12-31
# Data columns (total 11 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Adj Close  3754 non-null   float64
#  1   Close      3754 non-null   float64
#  2   High       3754 non-null   float64
#  3   Low        3754 non-null   float64
#  4   Open       3754 non-null   float64
#  5   Volume     3754 non-null   int64
#  6   DailyRet   3754 non-null   float64
#  7   20DayRet   3754 non-null   float64
#  8   20DayVol   3754 non-null   float64
#  9   Z20DayRet  3754 non-null   float64
#  10  Z20DayVol  3754 non-null   float64
# dtypes: float64(10), int64(1)
# memory usage: 351.9 KB
# Columns: ['Adj Close', 'Close', 'High', 'Low', 'Open', 'Volume', 'DailyRet', '20DayRet', '20DayVol', 'Z20DayRet', 'Z20DayVol']
#
# File: GE.csv
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 3754 entries, 2010-02-02 to 2024-12-31
# Data columns (total 11 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Adj Close  3754 non-null   float64
#  1   Close      3754 non-null   float64
#  2   High       3754 non-null   float64
#  3   Low        3754 non-null   float64
#  4   Open       3754 non-null   float64
#  5   Volume     3754 non-null   int64
#  6   DailyRet   3754 non-null   float64
#  7   20DayRet   3754 non-null   float64
#  8   20DayVol   3754 non-null   float64
#  9   Z20DayRet  3754 non-null   float64
#  10  Z20DayVol  3754 non-null   float64
# dtypes: float64(10), int64(1)
# memory usage: 351.9 KB
# Columns: ['Adj Close', 'Close', 'High', 'Low', 'Open', 'Volume', 'DailyRet', '20DayRet', '20DayVol', 'Z20DayRet', 'Z20DayVol']
#
# File: GILD.csv
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 3754 entries, 2010-02-02 to 2024-12-31
# Data columns (total 11 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Adj Close  3754 non-null   float64
#  1   Close      3754 non-null   float64
#  2   High       3754 non-null   float64
#  3   Low        3754 non-null   float64
#  4   Open       3754 non-null   float64
#  5   Volume     3754 non-null   int64
#  6   DailyRet   3754 non-null   float64
#  7   20DayRet   3754 non-null   float64
#  8   20DayVol   3754 non-null   float64
#  9   Z20DayRet  3754 non-null   float64
#  10  Z20DayVol  3754 non-null   float64
# dtypes: float64(10), int64(1)
# memory usage: 351.9 KB
# Columns: ['Adj Close', 'Close', 'High', 'Low', 'Open', 'Volume', 'DailyRet', '20DayRet', '20DayVol', 'Z20DayRet', 'Z20DayVol']
#
# File: GOOGL.csv
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 3754 entries, 2010-02-02 to 2024-12-31
# Data columns (total 11 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Adj Close  3754 non-null   float64
#  1   Close      3754 non-null   float64
#  2   High       3754 non-null   float64
#  3   Low        3754 non-null   float64
#  4   Open       3754 non-null   float64
#  5   Volume     3754 non-null   int64
#  6   DailyRet   3754 non-null   float64
#  7   20DayRet   3754 non-null   float64
#  8   20DayVol   3754 non-null   float64
#  9   Z20DayRet  3754 non-null   float64
#  10  Z20DayVol  3754 non-null   float64
# dtypes: float64(10), int64(1)
# memory usage: 351.9 KB
# Columns: ['Adj Close', 'Close', 'High', 'Low', 'Open', 'Volume', 'DailyRet', '20DayRet', '20DayVol', 'Z20DayRet', 'Z20DayVol']
#
# File: HON.csv
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 3754 entries, 2010-02-02 to 2024-12-31
# Data columns (total 11 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Adj Close  3754 non-null   float64
#  1   Close      3754 non-null   float64
#  2   High       3754 non-null   float64
#  3   Low        3754 non-null   float64
#  4   Open       3754 non-null   float64
#  5   Volume     3754 non-null   int64
#  6   DailyRet   3754 non-null   float64
#  7   20DayRet   3754 non-null   float64
#  8   20DayVol   3754 non-null   float64
#  9   Z20DayRet  3754 non-null   float64
#  10  Z20DayVol  3754 non-null   float64
# dtypes: float64(10), int64(1)
# memory usage: 351.9 KB
# Columns: ['Adj Close', 'Close', 'High', 'Low', 'Open', 'Volume', 'DailyRet', '20DayRet', '20DayVol', 'Z20DayRet', 'Z20DayVol']
#
# File: IBM.csv
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 3754 entries, 2010-02-02 to 2024-12-31
# Data columns (total 11 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Adj Close  3754 non-null   float64
#  1   Close      3754 non-null   float64
#  2   High       3754 non-null   float64
#  3   Low        3754 non-null   float64
#  4   Open       3754 non-null   float64
#  5   Volume     3754 non-null   int64
#  6   DailyRet   3754 non-null   float64
#  7   20DayRet   3754 non-null   float64
#  8   20DayVol   3754 non-null   float64
#  9   Z20DayRet  3754 non-null   float64
#  10  Z20DayVol  3754 non-null   float64
# dtypes: float64(10), int64(1)
# memory usage: 351.9 KB
# Columns: ['Adj Close', 'Close', 'High', 'Low', 'Open', 'Volume', 'DailyRet', '20DayRet', '20DayVol', 'Z20DayRet', 'Z20DayVol']
#
# File: INTC.csv
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 3754 entries, 2010-02-02 to 2024-12-31
# Data columns (total 11 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Adj Close  3754 non-null   float64
#  1   Close      3754 non-null   float64
#  2   High       3754 non-null   float64
#  3   Low        3754 non-null   float64
#  4   Open       3754 non-null   float64
#  5   Volume     3754 non-null   int64
#  6   DailyRet   3754 non-null   float64
#  7   20DayRet   3754 non-null   float64
#  8   20DayVol   3754 non-null   float64
#  9   Z20DayRet  3754 non-null   float64
#  10  Z20DayVol  3754 non-null   float64
# dtypes: float64(10), int64(1)
# memory usage: 351.9 KB
# Columns: ['Adj Close', 'Close', 'High', 'Low', 'Open', 'Volume', 'DailyRet', '20DayRet', '20DayVol', 'Z20DayRet', 'Z20DayVol']
#
# File: JPM.csv
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 3754 entries, 2010-02-02 to 2024-12-31
# Data columns (total 11 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Adj Close  3754 non-null   float64
#  1   Close      3754 non-null   float64
#  2   High       3754 non-null   float64
#  3   Low        3754 non-null   float64
#  4   Open       3754 non-null   float64
#  5   Volume     3754 non-null   int64
#  6   DailyRet   3754 non-null   float64
#  7   20DayRet   3754 non-null   float64
#  8   20DayVol   3754 non-null   float64
#  9   Z20DayRet  3754 non-null   float64
#  10  Z20DayVol  3754 non-null   float64
# dtypes: float64(10), int64(1)
# memory usage: 351.9 KB
# Columns: ['Adj Close', 'Close', 'High', 'Low', 'Open', 'Volume', 'DailyRet', '20DayRet', '20DayVol', 'Z20DayRet', 'Z20DayVol']
#
# File: KO.csv
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 3754 entries, 2010-02-02 to 2024-12-31
# Data columns (total 11 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Adj Close  3754 non-null   float64
#  1   Close      3754 non-null   float64
#  2   High       3754 non-null   float64
#  3   Low        3754 non-null   float64
#  4   Open       3754 non-null   float64
#  5   Volume     3754 non-null   int64
#  6   DailyRet   3754 non-null   float64
#  7   20DayRet   3754 non-null   float64
#  8   20DayVol   3754 non-null   float64
#  9   Z20DayRet  3754 non-null   float64
#  10  Z20DayVol  3754 non-null   float64
# dtypes: float64(10), int64(1)
# memory usage: 351.9 KB
# Columns: ['Adj Close', 'Close', 'High', 'Low', 'Open', 'Volume', 'DailyRet', '20DayRet', '20DayVol', 'Z20DayRet', 'Z20DayVol']
#
# File: LIN.csv
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 3754 entries, 2010-02-02 to 2024-12-31
# Data columns (total 11 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Adj Close  3754 non-null   float64
#  1   Close      3754 non-null   float64
#  2   High       3754 non-null   float64
#  3   Low        3754 non-null   float64
#  4   Open       3754 non-null   float64
#  5   Volume     3754 non-null   int64
#  6   DailyRet   3754 non-null   float64
#  7   20DayRet   3754 non-null   float64
#  8   20DayVol   3754 non-null   float64
#  9   Z20DayRet  3754 non-null   float64
#  10  Z20DayVol  3754 non-null   float64
# dtypes: float64(10), int64(1)
# memory usage: 351.9 KB
# Columns: ['Adj Close', 'Close', 'High', 'Low', 'Open', 'Volume', 'DailyRet', '20DayRet', '20DayVol', 'Z20DayRet', 'Z20DayVol']
#
# File: LMT.csv
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 3754 entries, 2010-02-02 to 2024-12-31
# Data columns (total 11 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Adj Close  3754 non-null   float64
#  1   Close      3754 non-null   float64
#  2   High       3754 non-null   float64
#  3   Low        3754 non-null   float64
#  4   Open       3754 non-null   float64
#  5   Volume     3754 non-null   int64
#  6   DailyRet   3754 non-null   float64
#  7   20DayRet   3754 non-null   float64
#  8   20DayVol   3754 non-null   float64
#  9   Z20DayRet  3754 non-null   float64
#  10  Z20DayVol  3754 non-null   float64
# dtypes: float64(10), int64(1)
# memory usage: 351.9 KB
# Columns: ['Adj Close', 'Close', 'High', 'Low', 'Open', 'Volume', 'DailyRet', '20DayRet', '20DayVol', 'Z20DayRet', 'Z20DayVol']
#
# File: MCD.csv
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 3754 entries, 2010-02-02 to 2024-12-31
# Data columns (total 11 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Adj Close  3754 non-null   float64
#  1   Close      3754 non-null   float64
#  2   High       3754 non-null   float64
#  3   Low        3754 non-null   float64
#  4   Open       3754 non-null   float64
#  5   Volume     3754 non-null   int64
#  6   DailyRet   3754 non-null   float64
#  7   20DayRet   3754 non-null   float64
#  8   20DayVol   3754 non-null   float64
#  9   Z20DayRet  3754 non-null   float64
#  10  Z20DayVol  3754 non-null   float64
# dtypes: float64(10), int64(1)
# memory usage: 351.9 KB
# Columns: ['Adj Close', 'Close', 'High', 'Low', 'Open', 'Volume', 'DailyRet', '20DayRet', '20DayVol', 'Z20DayRet', 'Z20DayVol']
#
# File: MDT.csv
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 3754 entries, 2010-02-02 to 2024-12-31
# Data columns (total 11 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Adj Close  3754 non-null   float64
#  1   Close      3754 non-null   float64
#  2   High       3754 non-null   float64
#  3   Low        3754 non-null   float64
#  4   Open       3754 non-null   float64
#  5   Volume     3754 non-null   int64
#  6   DailyRet   3754 non-null   float64
#  7   20DayRet   3754 non-null   float64
#  8   20DayVol   3754 non-null   float64
#  9   Z20DayRet  3754 non-null   float64
#  10  Z20DayVol  3754 non-null   float64
# dtypes: float64(10), int64(1)
# memory usage: 351.9 KB
# Columns: ['Adj Close', 'Close', 'High', 'Low', 'Open', 'Volume', 'DailyRet', '20DayRet', '20DayVol', 'Z20DayRet', 'Z20DayVol']
#
# File: META.csv
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 3155 entries, 2012-06-18 to 2024-12-31
# Data columns (total 11 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Adj Close  3155 non-null   float64
#  1   Close      3155 non-null   float64
#  2   High       3155 non-null   float64
#  3   Low        3155 non-null   float64
#  4   Open       3155 non-null   float64
#  5   Volume     3155 non-null   int64
#  6   DailyRet   3155 non-null   float64
#  7   20DayRet   3155 non-null   float64
#  8   20DayVol   3155 non-null   float64
#  9   Z20DayRet  3155 non-null   float64
#  10  Z20DayVol  3155 non-null   float64
# dtypes: float64(10), int64(1)
# memory usage: 295.8 KB
# Columns: ['Adj Close', 'Close', 'High', 'Low', 'Open', 'Volume', 'DailyRet', '20DayRet', '20DayVol', 'Z20DayRet', 'Z20DayVol']
#
# File: MMM.csv
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 3754 entries, 2010-02-02 to 2024-12-31
# Data columns (total 11 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Adj Close  3754 non-null   float64
#  1   Close      3754 non-null   float64
#  2   High       3754 non-null   float64
#  3   Low        3754 non-null   float64
#  4   Open       3754 non-null   float64
#  5   Volume     3754 non-null   int64
#  6   DailyRet   3754 non-null   float64
#  7   20DayRet   3754 non-null   float64
#  8   20DayVol   3754 non-null   float64
#  9   Z20DayRet  3754 non-null   float64
#  10  Z20DayVol  3754 non-null   float64
# dtypes: float64(10), int64(1)
# memory usage: 351.9 KB
# Columns: ['Adj Close', 'Close', 'High', 'Low', 'Open', 'Volume', 'DailyRet', '20DayRet', '20DayVol', 'Z20DayRet', 'Z20DayVol']
#
# File: MRK.csv
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 3754 entries, 2010-02-02 to 2024-12-31
# Data columns (total 11 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Adj Close  3754 non-null   float64
#  1   Close      3754 non-null   float64
#  2   High       3754 non-null   float64
#  3   Low        3754 non-null   float64
#  4   Open       3754 non-null   float64
#  5   Volume     3754 non-null   int64
#  6   DailyRet   3754 non-null   float64
#  7   20DayRet   3754 non-null   float64
#  8   20DayVol   3754 non-null   float64
#  9   Z20DayRet  3754 non-null   float64
#  10  Z20DayVol  3754 non-null   float64
# dtypes: float64(10), int64(1)
# memory usage: 351.9 KB
# Columns: ['Adj Close', 'Close', 'High', 'Low', 'Open', 'Volume', 'DailyRet', '20DayRet', '20DayVol', 'Z20DayRet', 'Z20DayVol']
#
# File: MSFT.csv
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 3754 entries, 2010-02-02 to 2024-12-31
# Data columns (total 11 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Adj Close  3754 non-null   float64
#  1   Close      3754 non-null   float64
#  2   High       3754 non-null   float64
#  3   Low        3754 non-null   float64
#  4   Open       3754 non-null   float64
#  5   Volume     3754 non-null   int64
#  6   DailyRet   3754 non-null   float64
#  7   20DayRet   3754 non-null   float64
#  8   20DayVol   3754 non-null   float64
#  9   Z20DayRet  3754 non-null   float64
#  10  Z20DayVol  3754 non-null   float64
# dtypes: float64(10), int64(1)
# memory usage: 351.9 KB
# Columns: ['Adj Close', 'Close', 'High', 'Low', 'Open', 'Volume', 'DailyRet', '20DayRet', '20DayVol', 'Z20DayRet', 'Z20DayVol']
#
# File: NFLX.csv
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 3754 entries, 2010-02-02 to 2024-12-31
# Data columns (total 11 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Adj Close  3754 non-null   float64
#  1   Close      3754 non-null   float64
#  2   High       3754 non-null   float64
#  3   Low        3754 non-null   float64
#  4   Open       3754 non-null   float64
#  5   Volume     3754 non-null   int64
#  6   DailyRet   3754 non-null   float64
#  7   20DayRet   3754 non-null   float64
#  8   20DayVol   3754 non-null   float64
#  9   Z20DayRet  3754 non-null   float64
#  10  Z20DayVol  3754 non-null   float64
# dtypes: float64(10), int64(1)
# memory usage: 351.9 KB
# Columns: ['Adj Close', 'Close', 'High', 'Low', 'Open', 'Volume', 'DailyRet', '20DayRet', '20DayVol', 'Z20DayRet', 'Z20DayVol']
#
# File: NKE.csv
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 3754 entries, 2010-02-02 to 2024-12-31
# Data columns (total 11 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Adj Close  3754 non-null   float64
#  1   Close      3754 non-null   float64
#  2   High       3754 non-null   float64
#  3   Low        3754 non-null   float64
#  4   Open       3754 non-null   float64
#  5   Volume     3754 non-null   int64
#  6   DailyRet   3754 non-null   float64
#  7   20DayRet   3754 non-null   float64
#  8   20DayVol   3754 non-null   float64
#  9   Z20DayRet  3754 non-null   float64
#  10  Z20DayVol  3754 non-null   float64
# dtypes: float64(10), int64(1)
# memory usage: 351.9 KB
# Columns: ['Adj Close', 'Close', 'High', 'Low', 'Open', 'Volume', 'DailyRet', '20DayRet', '20DayVol', 'Z20DayRet', 'Z20DayVol']
#
# File: NVDA.csv
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 3754 entries, 2010-02-02 to 2024-12-31
# Data columns (total 11 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Adj Close  3754 non-null   float64
#  1   Close      3754 non-null   float64
#  2   High       3754 non-null   float64
#  3   Low        3754 non-null   float64
#  4   Open       3754 non-null   float64
#  5   Volume     3754 non-null   int64
#  6   DailyRet   3754 non-null   float64
#  7   20DayRet   3754 non-null   float64
#  8   20DayVol   3754 non-null   float64
#  9   Z20DayRet  3754 non-null   float64
#  10  Z20DayVol  3754 non-null   float64
# dtypes: float64(10), int64(1)
# memory usage: 351.9 KB
# Columns: ['Adj Close', 'Close', 'High', 'Low', 'Open', 'Volume', 'DailyRet', '20DayRet', '20DayVol', 'Z20DayRet', 'Z20DayVol']
#
# File: ORCL.csv
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 3754 entries, 2010-02-02 to 2024-12-31
# Data columns (total 11 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Adj Close  3754 non-null   float64
#  1   Close      3754 non-null   float64
#  2   High       3754 non-null   float64
#  3   Low        3754 non-null   float64
#  4   Open       3754 non-null   float64
#  5   Volume     3754 non-null   int64
#  6   DailyRet   3754 non-null   float64
#  7   20DayRet   3754 non-null   float64
#  8   20DayVol   3754 non-null   float64
#  9   Z20DayRet  3754 non-null   float64
#  10  Z20DayVol  3754 non-null   float64
# dtypes: float64(10), int64(1)
# memory usage: 351.9 KB
# Columns: ['Adj Close', 'Close', 'High', 'Low', 'Open', 'Volume', 'DailyRet', '20DayRet', '20DayVol', 'Z20DayRet', 'Z20DayVol']
#
# File: PEP.csv
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 3754 entries, 2010-02-02 to 2024-12-31
# Data columns (total 11 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Adj Close  3754 non-null   float64
#  1   Close      3754 non-null   float64
#  2   High       3754 non-null   float64
#  3   Low        3754 non-null   float64
#  4   Open       3754 non-null   float64
#  5   Volume     3754 non-null   int64
#  6   DailyRet   3754 non-null   float64
#  7   20DayRet   3754 non-null   float64
#  8   20DayVol   3754 non-null   float64
#  9   Z20DayRet  3754 non-null   float64
#  10  Z20DayVol  3754 non-null   float64
# dtypes: float64(10), int64(1)
# memory usage: 351.9 KB
# Columns: ['Adj Close', 'Close', 'High', 'Low', 'Open', 'Volume', 'DailyRet', '20DayRet', '20DayVol', 'Z20DayRet', 'Z20DayVol']
#
# File: PFE.csv
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 3754 entries, 2010-02-02 to 2024-12-31
# Data columns (total 11 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Adj Close  3754 non-null   float64
#  1   Close      3754 non-null   float64
#  2   High       3754 non-null   float64
#  3   Low        3754 non-null   float64
#  4   Open       3754 non-null   float64
#  5   Volume     3754 non-null   int64
#  6   DailyRet   3754 non-null   float64
#  7   20DayRet   3754 non-null   float64
#  8   20DayVol   3754 non-null   float64
#  9   Z20DayRet  3754 non-null   float64
#  10  Z20DayVol  3754 non-null   float64
# dtypes: float64(10), int64(1)
# memory usage: 351.9 KB
# Columns: ['Adj Close', 'Close', 'High', 'Low', 'Open', 'Volume', 'DailyRet', '20DayRet', '20DayVol', 'Z20DayRet', 'Z20DayVol']
#
# File: PYPL.csv
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 2370 entries, 2015-08-03 to 2024-12-31
# Data columns (total 11 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Adj Close  2370 non-null   float64
#  1   Close      2370 non-null   float64
#  2   High       2370 non-null   float64
#  3   Low        2370 non-null   float64
#  4   Open       2370 non-null   float64
#  5   Volume     2370 non-null   int64
#  6   DailyRet   2370 non-null   float64
#  7   20DayRet   2370 non-null   float64
#  8   20DayVol   2370 non-null   float64
#  9   Z20DayRet  2370 non-null   float64
#  10  Z20DayVol  2370 non-null   float64
# dtypes: float64(10), int64(1)
# memory usage: 222.2 KB
# Columns: ['Adj Close', 'Close', 'High', 'Low', 'Open', 'Volume', 'DailyRet', '20DayRet', '20DayVol', 'Z20DayRet', 'Z20DayVol']
#
# File: QCOM.csv
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 3754 entries, 2010-02-02 to 2024-12-31
# Data columns (total 11 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Adj Close  3754 non-null   float64
#  1   Close      3754 non-null   float64
#  2   High       3754 non-null   float64
#  3   Low        3754 non-null   float64
#  4   Open       3754 non-null   float64
#  5   Volume     3754 non-null   int64
#  6   DailyRet   3754 non-null   float64
#  7   20DayRet   3754 non-null   float64
#  8   20DayVol   3754 non-null   float64
#  9   Z20DayRet  3754 non-null   float64
#  10  Z20DayVol  3754 non-null   float64
# dtypes: float64(10), int64(1)
# memory usage: 351.9 KB
# Columns: ['Adj Close', 'Close', 'High', 'Low', 'Open', 'Volume', 'DailyRet', '20DayRet', '20DayVol', 'Z20DayRet', 'Z20DayVol']
#
# File: SAP.csv
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 3754 entries, 2010-02-02 to 2024-12-31
# Data columns (total 11 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Adj Close  3754 non-null   float64
#  1   Close      3754 non-null   float64
#  2   High       3754 non-null   float64
#  3   Low        3754 non-null   float64
#  4   Open       3754 non-null   float64
#  5   Volume     3754 non-null   int64
#  6   DailyRet   3754 non-null   float64
#  7   20DayRet   3754 non-null   float64
#  8   20DayVol   3754 non-null   float64
#  9   Z20DayRet  3754 non-null   float64
#  10  Z20DayVol  3754 non-null   float64
# dtypes: float64(10), int64(1)
# memory usage: 351.9 KB
# Columns: ['Adj Close', 'Close', 'High', 'Low', 'Open', 'Volume', 'DailyRet', '20DayRet', '20DayVol', 'Z20DayRet', 'Z20DayVol']
#
# File: SBUX.csv
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 3754 entries, 2010-02-02 to 2024-12-31
# Data columns (total 11 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Adj Close  3754 non-null   float64
#  1   Close      3754 non-null   float64
#  2   High       3754 non-null   float64
#  3   Low        3754 non-null   float64
#  4   Open       3754 non-null   float64
#  5   Volume     3754 non-null   int64
#  6   DailyRet   3754 non-null   float64
#  7   20DayRet   3754 non-null   float64
#  8   20DayVol   3754 non-null   float64
#  9   Z20DayRet  3754 non-null   float64
#  10  Z20DayVol  3754 non-null   float64
# dtypes: float64(10), int64(1)
# memory usage: 351.9 KB
# Columns: ['Adj Close', 'Close', 'High', 'Low', 'Open', 'Volume', 'DailyRet', '20DayRet', '20DayVol', 'Z20DayRet', 'Z20DayVol']
#
# File: SPGI.csv
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 3754 entries, 2010-02-02 to 2024-12-31
# Data columns (total 11 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Adj Close  3754 non-null   float64
#  1   Close      3754 non-null   float64
#  2   High       3754 non-null   float64
#  3   Low        3754 non-null   float64
#  4   Open       3754 non-null   float64
#  5   Volume     3754 non-null   int64
#  6   DailyRet   3754 non-null   float64
#  7   20DayRet   3754 non-null   float64
#  8   20DayVol   3754 non-null   float64
#  9   Z20DayRet  3754 non-null   float64
#  10  Z20DayVol  3754 non-null   float64
# dtypes: float64(10), int64(1)
# memory usage: 351.9 KB
# Columns: ['Adj Close', 'Close', 'High', 'Low', 'Open', 'Volume', 'DailyRet', '20DayRet', '20DayVol', 'Z20DayRet', 'Z20DayVol']
#
# File: T.csv
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 3754 entries, 2010-02-02 to 2024-12-31
# Data columns (total 11 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Adj Close  3754 non-null   float64
#  1   Close      3754 non-null   float64
#  2   High       3754 non-null   float64
#  3   Low        3754 non-null   float64
#  4   Open       3754 non-null   float64
#  5   Volume     3754 non-null   int64
#  6   DailyRet   3754 non-null   float64
#  7   20DayRet   3754 non-null   float64
#  8   20DayVol   3754 non-null   float64
#  9   Z20DayRet  3754 non-null   float64
#  10  Z20DayVol  3754 non-null   float64
# dtypes: float64(10), int64(1)
# memory usage: 351.9 KB
# Columns: ['Adj Close', 'Close', 'High', 'Low', 'Open', 'Volume', 'DailyRet', '20DayRet', '20DayVol', 'Z20DayRet', 'Z20DayVol']
#
# File: TSLA.csv
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 3632 entries, 2010-07-28 to 2024-12-31
# Data columns (total 11 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Adj Close  3632 non-null   float64
#  1   Close      3632 non-null   float64
#  2   High       3632 non-null   float64
#  3   Low        3632 non-null   float64
#  4   Open       3632 non-null   float64
#  5   Volume     3632 non-null   int64
#  6   DailyRet   3632 non-null   float64
#  7   20DayRet   3632 non-null   float64
#  8   20DayVol   3632 non-null   float64
#  9   Z20DayRet  3632 non-null   float64
#  10  Z20DayVol  3632 non-null   float64
# dtypes: float64(10), int64(1)
# memory usage: 340.5 KB
# Columns: ['Adj Close', 'Close', 'High', 'Low', 'Open', 'Volume', 'DailyRet', '20DayRet', '20DayVol', 'Z20DayRet', 'Z20DayVol']
#
# File: TXN.csv
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 3754 entries, 2010-02-02 to 2024-12-31
# Data columns (total 11 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Adj Close  3754 non-null   float64
#  1   Close      3754 non-null   float64
#  2   High       3754 non-null   float64
#  3   Low        3754 non-null   float64
#  4   Open       3754 non-null   float64
#  5   Volume     3754 non-null   int64
#  6   DailyRet   3754 non-null   float64
#  7   20DayRet   3754 non-null   float64
#  8   20DayVol   3754 non-null   float64
#  9   Z20DayRet  3754 non-null   float64
#  10  Z20DayVol  3754 non-null   float64
# dtypes: float64(10), int64(1)
# memory usage: 351.9 KB
# Columns: ['Adj Close', 'Close', 'High', 'Low', 'Open', 'Volume', 'DailyRet', '20DayRet', '20DayVol', 'Z20DayRet', 'Z20DayVol']
#
# File: UNH.csv
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 3754 entries, 2010-02-02 to 2024-12-31
# Data columns (total 11 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Adj Close  3754 non-null   float64
#  1   Close      3754 non-null   float64
#  2   High       3754 non-null   float64
#  3   Low        3754 non-null   float64
#  4   Open       3754 non-null   float64
#  5   Volume     3754 non-null   int64
#  6   DailyRet   3754 non-null   float64
#  7   20DayRet   3754 non-null   float64
#  8   20DayVol   3754 non-null   float64
#  9   Z20DayRet  3754 non-null   float64
#  10  Z20DayVol  3754 non-null   float64
# dtypes: float64(10), int64(1)
# memory usage: 351.9 KB
# Columns: ['Adj Close', 'Close', 'High', 'Low', 'Open', 'Volume', 'DailyRet', '20DayRet', '20DayVol', 'Z20DayRet', 'Z20DayVol']
#
# File: V.csv
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 3754 entries, 2010-02-02 to 2024-12-31
# Data columns (total 11 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Adj Close  3754 non-null   float64
#  1   Close      3754 non-null   float64
#  2   High       3754 non-null   float64
#  3   Low        3754 non-null   float64
#  4   Open       3754 non-null   float64
#  5   Volume     3754 non-null   int64
#  6   DailyRet   3754 non-null   float64
#  7   20DayRet   3754 non-null   float64
#  8   20DayVol   3754 non-null   float64
#  9   Z20DayRet  3754 non-null   float64
#  10  Z20DayVol  3754 non-null   float64
# dtypes: float64(10), int64(1)
# memory usage: 351.9 KB
# Columns: ['Adj Close', 'Close', 'High', 'Low', 'Open', 'Volume', 'DailyRet', '20DayRet', '20DayVol', 'Z20DayRet', 'Z20DayVol']
#
# File: WMT.csv
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 3754 entries, 2010-02-02 to 2024-12-31
# Data columns (total 11 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Adj Close  3754 non-null   float64
#  1   Close      3754 non-null   float64
#  2   High       3754 non-null   float64
#  3   Low        3754 non-null   float64
#  4   Open       3754 non-null   float64
#  5   Volume     3754 non-null   int64
#  6   DailyRet   3754 non-null   float64
#  7   20DayRet   3754 non-null   float64
#  8   20DayVol   3754 non-null   float64
#  9   Z20DayRet  3754 non-null   float64
#  10  Z20DayVol  3754 non-null   float64
# dtypes: float64(10), int64(1)
# memory usage: 351.9 KB
# Columns: ['Adj Close', 'Close', 'High', 'Low', 'Open', 'Volume', 'DailyRet', '20DayRet', '20DayVol', 'Z20DayRet', 'Z20DayVol']
#
# File: ZTS.csv
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 2979 entries, 2013-03-04 to 2024-12-31
# Data columns (total 11 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Adj Close  2979 non-null   float64
#  1   Close      2979 non-null   float64
#  2   High       2979 non-null   float64
#  3   Low        2979 non-null   float64
#  4   Open       2979 non-null   float64
#  5   Volume     2979 non-null   int64
#  6   DailyRet   2979 non-null   float64
#  7   20DayRet   2979 non-null   float64
#  8   20DayVol   2979 non-null   float64
#  9   Z20DayRet  2979 non-null   float64
#  10  Z20DayVol  2979 non-null   float64
# dtypes: float64(10), int64(1)
# memory usage: 279.3 KB
# Columns: ['Adj Close', 'Close', 'High', 'Low', 'Open', 'Volume', 'DailyRet', '20DayRet', '20DayVol', 'Z20DayRet', 'Z20DayVol']

# %%
for file in os.listdir(data_folder):
    if file.endswith(".csv"):
        file_path = os.path.join(data_folder, file)
        print(f"Processing {file} ...")
        df = pd.read_csv(file_path)
        df['Date'] = pd.to_datetime(df['Date'])
        df = df.sort_values('Date')
        df["DailyRet"] = df["Adj Close"].pct_change()
        df["20DayRet"] = df["Adj Close"].pct_change(periods=20)
        df["20DayVol"] = df["DailyRet"].rolling(window=20).std()
        df["Z20DayRet"] = (df["20DayRet"] - df["20DayRet"].mean()) / df["20DayRet"].std()
        df["Z20DayVol"] = (df["20DayVol"] - df["20DayVol"].mean()) / df["20DayVol"].std()
        df = df.dropna().reset_index(drop=True)
        df.to_csv(file_path, index=False)
print("All stocks processed successfully!")
# Out:
# Processing AAPL.csv ...
# Processing ABT.csv ...
# Processing ADBE.csv ...
# Processing AMGN.csv ...
# Processing AMZN.csv ...
# Processing BA.csv ...
# Processing BKNG.csv ...
# Processing BLK.csv ...
# Processing BMY.csv ...
# Processing CAT.csv ...
# Processing COST.csv ...
# Processing CRM.csv ...
# Processing CSCO.csv ...
# Processing CVX.csv ...
# Processing DHR.csv ...
# Processing DIS.csv ...
# Processing FIS.csv ...
# Processing GE.csv ...
# Processing GILD.csv ...
# Processing GOOGL.csv ...
# Processing HON.csv ...
# Processing IBM.csv ...
# Processing INTC.csv ...
# Processing JPM.csv ...
# Processing KO.csv ...
# Processing LIN.csv ...
# Processing LMT.csv ...
# Processing MCD.csv ...
# Processing MDT.csv ...
# Processing META.csv ...
# Processing MMM.csv ...
# Processing MRK.csv ...
# Processing MSFT.csv ...
# Processing NFLX.csv ...
# Processing NKE.csv ...
# Processing NVDA.csv ...
# Processing ORCL.csv ...
# Processing PEP.csv ...
# Processing PFE.csv ...
# Processing PYPL.csv ...
# Processing QCOM.csv ...
# Processing SAP.csv ...
# Processing SBUX.csv ...
# Processing SPGI.csv ...
# Processing T.csv ...
# Processing TSLA.csv ...
# Processing TXN.csv ...
# Processing UNH.csv ...
# Processing V.csv ...
# Processing WMT.csv ...
# Processing ZTS.csv ...
# All stocks processed successfully!

# %%
all_stocks = []
for file in os.listdir(data_folder):
    if file.endswith(".csv"):
        file_path = os.path.join(data_folder, file)
        ticker = os.path.splitext(file)[0].upper() 
        df = pd.read_csv(file_path)
        df['Date'] = pd.to_datetime(df['Date'])
        df = df.sort_values('Date')
        df.set_index('Date', inplace=True)
        df.columns = pd.MultiIndex.from_product([[ticker], df.columns])
        all_stocks.append(df)
merged_df = pd.concat(all_stocks, axis=1, join='inner')
merged_df = merged_df.sort_index(axis=1, level=0)
merged_df.to_csv("data/processed/MultiIndex_stock_data.csv")
merged_df.head()
# Out:
#                 AAPL                                                       \
#             20DayRet  20DayVol  Adj Close      Close  DailyRet       High
# Date
# 2015-08-03 -0.060000  0.016946  26.496563  29.610001 -0.023578  30.642500
# 2015-08-04 -0.087915  0.018152  25.646452  28.660000 -0.032084  29.424999
# 2015-08-05 -0.058497  0.017648  25.816473  28.850000  0.006629  29.360001
# 2015-08-06 -0.036803  0.017184  25.872654  28.782499  0.002176  29.125000
# 2015-08-07 -0.058705  0.015893  25.960295  28.879999  0.003387  29.062500
#
#                                                        ...       ZTS  \
#                   Low       Open     Volume Z20DayRet  ...  20DayVol
# Date                                                   ...
# 2015-08-03  29.379999  30.375000  279904000 -1.082105  ...  0.012589
# 2015-08-04  28.312500  29.355000  496554400 -1.447145  ...  0.012421
# 2015-08-05  28.025000  28.237499  397250400 -1.062455  ...  0.010307
# 2015-08-06  28.530001  28.992500  211612000 -0.778759  ...  0.010506
# 2015-08-07  28.625000  28.645000  154681600 -1.065168  ...  0.010395
#
#                                                                              \
#             Adj Close      Close  DailyRet       High        Low       Open
# Date
# 2015-08-03  44.814980  48.480000 -0.010208  49.490002  47.990002  49.160000
# 2015-08-04  45.157017  48.849998  0.007632  50.000000  48.279999  49.110001
# 2015-08-05  44.935158  48.610001 -0.004913  49.119999  48.520000  48.950001
# 2015-08-06  44.630096  48.279999 -0.006789  50.250000  47.970001  49.560001
# 2015-08-07  44.657825  48.310001  0.000621  48.470001  47.439999  48.119999
#
#
#              Volume Z20DayRet Z20DayVol
# Date
# 2015-08-03  3559500 -0.192182 -0.291302
# 2015-08-04  4867300  0.103570 -0.315848
# 2015-08-05  4118200  0.509973 -0.624579
# 2015-08-06  3223400  0.365208 -0.595568
# 2015-08-07  3466000  0.238504 -0.611735
#
# [5 rows x 561 columns]

# %%
merged_df.shape, merged_df.index.min().date(), merged_df.index.max().date(), merged_df.columns.levels[0][:5]
# Out:
# ((2370, 561),
#  datetime.date(2015, 8, 3),
#  datetime.date(2024, 12, 31),
#  Index(['AAPL', 'ABT', 'ADBE', 'AMGN', 'AMZN'], dtype='object'))
